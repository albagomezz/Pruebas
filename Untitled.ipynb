# %%
# !git init
# Out:
# Initialized empty Git repository in C:/Users/Alba/Desktop/Masteres/Untitled Folder/.git/

# %%
# !git add .

# %%
# !git commit -m "Intento 1"
# Out:
# [master (root-commit) 886d29f] Intento 1
#  2 files changed, 12 insertions(+)
#  create mode 100644 .ipynb_checkpoints/Untitled-checkpoint.ipynb
#  create mode 100644 Untitled.ipynb

# %%
# !git remote add origin https://github.com/albagomezz/Pruebas

# %%
# !git add .

# %%
# !git commit -m "primer commit"
# Out:
# [master 2631fcc] primer commit
#  1 file changed, 99 insertions(+), 2 deletions(-)

# %%
# !git branch -M main
# !git push -u origin main
# Out:
# branch 'main' set up to track 'origin/main'.
# To https://github.com/albagomezz/Pruebas
#  * [new branch]      main -> main

# %% [markdown]
# Analisis de datos bank

# %%
import pandas as pd
import seaborn as sns
import plotly.express as px
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("bank.csv", sep = ';')

# %%
data.head()
# Out:
#    age          job  marital  education default  balance housing loan  \
# 0   30   unemployed  married    primary      no     1787      no   no
# 1   33     services  married  secondary      no     4789     yes  yes
# 2   35   management   single   tertiary      no     1350     yes   no
# 3   30   management  married   tertiary      no     1476     yes  yes
# 4   59  blue-collar  married  secondary      no        0     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  cellular   19   oct        79         1     -1         0  unknown  no
# 1  cellular   11   may       220         1    339         4  failure  no
# 2  cellular   16   apr       185         1    330         1  failure  no
# 3   unknown    3   jun       199         4     -1         0  unknown  no
# 4   unknown    5   may       226         1     -1         0  unknown  no

# %%
data.shape
# Out:
# (4521, 17)

# %%
data.isnull().sum()
# Out:
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# y            0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.describe()
# Out:
#                age       balance          day     duration     campaign  \
# count  4521.000000   4521.000000  4521.000000  4521.000000  4521.000000
# mean     41.170095   1422.657819    15.915284   263.961292     2.793630
# std      10.576211   3009.638142     8.247667   259.856633     3.109807
# min      19.000000  -3313.000000     1.000000     4.000000     1.000000
# 25%      33.000000     69.000000     9.000000   104.000000     1.000000
# 50%      39.000000    444.000000    16.000000   185.000000     2.000000
# 75%      49.000000   1480.000000    21.000000   329.000000     3.000000
# max      87.000000  71188.000000    31.000000  3025.000000    50.000000
#
#              pdays     previous
# count  4521.000000  4521.000000
# mean     39.766645     0.542579
# std     100.121124     1.693562
# min      -1.000000     0.000000
# 25%      -1.000000     0.000000
# 50%      -1.000000     0.000000
# 75%      -1.000000     0.000000
# max     871.000000    25.000000

# %%
sns.histplot(data["age"])
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
sns.histplot(data["balance"])
# Out:
# <Axes: xlabel='balance', ylabel='Count'>

# %%
fig=px.bar(x=data["age"],y=data["balance"])
fig.update_layout(
    xaxis_title='Edad (años)',  # Cambia el nombre del eje X
    yaxis_title='Balance',   # Cambia el nombre del eje Y
)
fig.show()
# Out:
# <div>                            <div id="b4a1b83e-1edd-474b-bac0-0dfb70be0244" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b4a1b83e-1edd-474b-bac0-0dfb70be0244")) {                    Plotly.newPlot(                        "b4a1b83e-1edd-474b-bac0-0dfb70be0244",                        [{"alignmentgroup":"True","hovertemplate":"x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":[30,33,35,30,59,35,36,39,41,43,39,43,36,20,31,40,56,37,25,31,38,42,44,44,26,41,55,67,56,53,68,31,59,32,49,42,78,32,33,23,38,36,52,32,32,34,55,26,32,61,45,37,38,34,53,48,57,33,36,54,41,63,48,48,56,51,31,29,41,32,37,42,31,41,56,54,41,4
# ...

# %%
plt.figure()
plt.hist(data['age'])
plt.show()

# %%
fig = px.histogram(data, x='age')
fig.show()
# Out:
# <div>                            <div id="843c7060-a51e-45b4-8597-18895d629cbc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("843c7060-a51e-45b4-8597-18895d629cbc")) {                    Plotly.newPlot(                        "843c7060-a51e-45b4-8597-18895d629cbc",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"age=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":[30,33,35,30,59,35,36,39,41,43,39,43,36,20,31,40,56,37,25,31,38,42,44,44,26,41,55,67,56,53,68,31,59,32,49,42,78,32,33,23,38,36,52,32,32,34,55,26,32,61,45,37,38,34,53,48,57,33,36,54,41,63,48,48,56,51,31,29,41,32,37,42,31,41,56,54,41,40
# ...

# %%
fig = px.histogram(data, x='y')
fig.show()
# Out:
# <div>                            <div id="265b0727-7bf8-4b74-beb3-6b0d45d42c0f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("265b0727-7bf8-4b74-beb3-6b0d45d42c0f")) {                    Plotly.newPlot(                        "265b0727-7bf8-4b74-beb3-6b0d45d42c0f",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"y=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":["no","no","no","no","no","no","no","no","no","no","no","no","no","yes","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","yes","no","no","yes","yes","no","yes","yes","yes","no","no","no","no","no","no","no
# ...

# %%
# Agrupamos por 'job' y sumamos 'y'
a = data.groupby(['job', 'y']).size().reset_index(name='count')

# Crear el gráfico de barras
plt.figure(figsize=(10, 6))
sns.barplot(x='job', y='count', hue='y', data=a)
plt.show()

# %%
# Agrupamos por 'job' y sumamos 'y'
a = data.groupby(['marital', 'y']).size().reset_index(name='count')

# Crear el gráfico de barras
plt.figure(figsize=(10, 6))
sns.barplot(x='marital', y='count', hue='y', data=a)
plt.show()

# %%
sns.boxplot(x="balance", y="y", data=data)
# Out:
# <Axes: xlabel='balance', ylabel='y'>

# %%
! git add .
! git commit
